# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# reading the data set
df=pd.read_csv('adult.csv')
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df.shape
# Out:
# (48842, 15)

# %% [markdown]
# # In this project, we will discuss:
# - How to fetch random samples from the Dataset?
# - isin
# - between
# - unique
# - dropna
# - replace
# - duplicated
# - drop_duplicates
# - astype
# - apply
# - What is Univariate analysis?
# - What is Bivariate analysis?
# - Memory Optimization
#
# --------------------------------------------------
#  # Questions :
#
#
# 1.Display Top 10 Rows of The Dataset
#
# 2. Check Last 10 Rows of The Dataset
#
# 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)
#
# 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement
#
# 5. Fetch Random Sample From the Dataset (50%)
#
# 6.Check Null Values In The Dataset
#
# 7.Perform Data Cleaning [ Replace '?' with NaN ]
#
# 8. Drop all The Missing Values
#
# 9. Check For Duplicate Data and Drop Them

# %%
# 1.
df.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
# 2.
df.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %%
#3. 
print('number of rows are :',df.shape[0])
print('number of columns are :',df.shape[1])
# Out:
# number of rows are : 48842
# number of columns are : 15

# %%
# 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
# 5. Fetch Random Sample From the Dataset (50%)
df.sample(frac=0.50,random_state=100)  # here random state help to keep first 100 rows constant and remaining rows are randomly picked
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 12393   37    Private  110331   Prof-school               15
# 48701   23    Private   45834     Bachelors               13
# 17918   28    Private   89718       HS-grad                9
# 11352   30    Private  351770           9th                5
# 36198   31    Private  164190          10th                6
# ...    ...        ...     ...           ...              ...
# 48573   41    Private  318046  Some-college               10
# 47252   41  Local-gov   33658  Some-college               10
# 33142   69    Private  312653  Some-college               10
# 2965    21          ?  334593  Some-college               10
# 32089   34    Private  186269       HS-grad                9
#
#            marital-status        occupation   relationship   race  gender  \
# 12393  Married-civ-spouse     Other-service           Wife  White  Female
# 48701       Never-married   Exec-managerial  Not-in-family  White  Female
# ...

# %%
# 6.Check Null Values In The Dataset
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
# to check column wise 
df.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 48837    0
# 48838    0
# 48839    0
# 48840    0
# 48841    0
# Length: 48842, dtype: int64

# %%
# we can see with help of visualization also
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# 7..Perform Data Cleaning [ Replace '?' with NaN ]
df.tail(20)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 48822   41                 ?  202822       HS-grad                9
# 48823   72                 ?  129912       HS-grad                9
# 48824   45         Local-gov  119199    Assoc-acdm               12
# 48825   31           Private  199655       Masters               14
# 48826   39         Local-gov  111499    Assoc-acdm               12
# 48827   37           Private  198216    Assoc-acdm               12
# 48828   43           Private  260761       HS-grad                9
# 48829   65  Self-emp-not-inc   99359   Prof-school               15
# 48830   43         State-gov  255835  Some-college               10
# 48831   43  Self-emp-not-inc   27242  Some-college               10
# 48832   32           Private   34066          10th                6
# 48833   43           Private   84661     Assoc-voc               11
# 48834   32           Private  116138       Masters               14
# ...

# %%
df.iloc[4000:4025]
# Out:
#       age         workclass  fnlwgt     education  educational-num  \
# 4000   31         State-gov  227864       HS-grad                9
# 4001   31           Private  173858       HS-grad                9
# 4002   51           Private   30012       HS-grad                9
# 4003   20                 ?   50163  Some-college               10
# 4004   50         State-gov  143822     Doctorate               16
# 4005   19                 ?  497414       7th-8th                4
# 4006   30           Private  235109     Assoc-voc               11
# 4007   32           Private  339196       HS-grad                9
# 4008   61           Private  181028       Masters               14
# 4009   43           Private   59460     Bachelors               13
# 4010   21           Private   97212       HS-grad                9
# 4011   32           Private  103642     Assoc-voc               11
# 4012   41           Private   70447  Some-college               10
# ...

# %%
# we are going to implement the isin method 
df.isin(['?']).sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df['workclass']=df['workclass'].replace('?',np.nan)

# %%
df['occupation']=df['occupation'].replace('?',np.nan)
df['native-country']=df['native-country'].replace('?',np.nan)

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
df.isnull().sum()*100/len(df)
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %%
#8.Drop all The Missing Values
# here we can see the how many null values are present
df=df.drop(['workclass','occupation','native-country'],axis='columns')
df.head()
# Out:
#    age  fnlwgt     education  educational-num      marital-status  \
# 0   25  226802          11th                7       Never-married
# 1   38   89814       HS-grad                9  Married-civ-spouse
# 2   28  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44  160323  Some-college               10  Married-civ-spouse
# 4   18  103497  Some-college               10       Never-married
#
#   relationship   race  gender  capital-gain  capital-loss  hours-per-week  \
# 0    Own-child  Black    Male             0             0              40
# 1      Husband  White    Male             0             0              50
# 2      Husband  White    Male             0             0              40
# 3      Husband  Black    Male          7688             0              40
# 4    Own-child  White  Female             0             0              30
#
#   income
# 0  <=50K
# 1  <=50K
# 2   >50K
# 3   >50K
# 4  <=50K

# %% [markdown]
# # we can replace with how method
# df.dropna(how='any',inplace=True)

# %%
df.isnull().sum()
# Out:
# age                0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# income             0
# dtype: int64

# %%
df.shape
# Out:
# (48842, 12)

# %%
# 9.Check For Duplicate Data and Drop Them
dup=df.duplicated().any()
dup
# Out:
# True

# %%
# drop the duplicated value from the data 
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (48640, 12)

# %%
# 10. Overal Statistics of the data 
df.describe().T
# Out:
#                    count           mean            std      min       25%  \
# age              48640.0      38.669346      13.710649     17.0      28.0
# fnlwgt           48640.0  189673.021279  105672.309993  12285.0  117528.0
# educational-num  48640.0      10.078845       2.571267      1.0       9.0
# capital-gain     48640.0    1083.240070    7466.886242      0.0       0.0
# capital-loss     48640.0      87.865707     403.800998      0.0       0.0
# hours-per-week   48640.0      40.431373      12.405278      1.0      40.0
#
#                       50%       75%        max
# age                  37.0      48.0       90.0
# fnlwgt           178109.0  237625.5  1490400.0
# educational-num      10.0      12.0       16.0
# capital-gain          0.0       0.0    99999.0
# capital-loss          0.0       0.0     4356.0
# hours-per-week       40.0      45.0       99.0

# %%
df.describe(include='all')
# Out:
#                  age        fnlwgt education  educational-num  \
# count   48640.000000  4.864000e+04     48640     48640.000000
# unique           NaN           NaN        16              NaN
# top              NaN           NaN   HS-grad              NaN
# freq             NaN           NaN     15704              NaN
# mean       38.669346  1.896730e+05       NaN        10.078845
# std        13.710649  1.056723e+05       NaN         2.571267
# min        17.000000  1.228500e+04       NaN         1.000000
# 25%        28.000000  1.175280e+05       NaN         9.000000
# 50%        37.000000  1.781090e+05       NaN        10.000000
# 75%        48.000000  2.376255e+05       NaN        12.000000
# max        90.000000  1.490400e+06       NaN        16.000000
#
#             marital-status relationship   race gender  capital-gain  \
# count                48640        48640  48640  48640  48640.000000
# unique                   7            6      5      2           NaN
# ...

# %%
df.columns
# Out:
# Index(['age', 'fnlwgt', 'education', 'educational-num', 'marital-status',
#        'relationship', 'race', 'gender', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'income'],
#       dtype='object')

# %%
# lets know how many unique values are present in education 
df['education'].unique()
# Out:
# array(['11th', 'HS-grad', 'Assoc-acdm', 'Some-college', '10th',
#        'Prof-school', '7th-8th', 'Bachelors', 'Masters', 'Doctorate',
#        '5th-6th', 'Assoc-voc', '9th', '12th', '1st-4th', 'Preschool'],
#       dtype=object)

# %%
df['educational-num'].unique()
# Out:
# array([ 7,  9, 12, 10,  6, 15,  4, 13, 14, 16,  3, 11,  5,  8,  2,  1],
#       dtype=int64)

# %%
df=df.drop('educational-num',axis='columns')

# %%
df.describe(include='all')
# Out:
#                  age        fnlwgt education      marital-status relationship  \
# count   48640.000000  4.864000e+04     48640               48640        48640
# unique           NaN           NaN        16                   7            6
# top              NaN           NaN   HS-grad  Married-civ-spouse      Husband
# freq             NaN           NaN     15704               22289        19628
# mean       38.669346  1.896730e+05       NaN                 NaN          NaN
# std        13.710649  1.056723e+05       NaN                 NaN          NaN
# min        17.000000  1.228500e+04       NaN                 NaN          NaN
# 25%        28.000000  1.175280e+05       NaN                 NaN          NaN
# 50%        37.000000  1.781090e+05       NaN                 NaN          NaN
# 75%        48.000000  2.376255e+05       NaN                 NaN          NaN
# max        90.000000  1.490400e+06       NaN                 NaN          NaN
#
# ...

# %%
# As you observe the above data table you can find the 75% of capital-gain and capital-loss are 0 so we can drop that column
df=df.drop(['capital-gain','capital-loss'],axis='columns')

# %%
df.describe(include='all')
# Out:
#                  age        fnlwgt education      marital-status relationship  \
# count   48640.000000  4.864000e+04     48640               48640        48640
# unique           NaN           NaN        16                   7            6
# top              NaN           NaN   HS-grad  Married-civ-spouse      Husband
# freq             NaN           NaN     15704               22289        19628
# mean       38.669346  1.896730e+05       NaN                 NaN          NaN
# std        13.710649  1.056723e+05       NaN                 NaN          NaN
# min        17.000000  1.228500e+04       NaN                 NaN          NaN
# 25%        28.000000  1.175280e+05       NaN                 NaN          NaN
# 50%        37.000000  1.781090e+05       NaN                 NaN          NaN
# 75%        48.000000  2.376255e+05       NaN                 NaN          NaN
# max        90.000000  1.490400e+06       NaN                 NaN          NaN
#
# ...

# %% [markdown]
# # UNIVARIENT ANALYSIS
# THIS IS done by taking the one variable

# %%
df.columns
# Out:
# Index(['age', 'fnlwgt', 'education', 'marital-status', 'relationship', 'race',
#        'gender', 'hours-per-week', 'income'],
#       dtype='object')

# %%
# 12. What is the distribution of the data
df['age'].describe()
# Out:
# count    48640.000000
# mean        38.669346
# std         13.710649
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %%
df['age'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Most of the Age people from the 20-45 are present

# %%
#13. Find the number of Person having age between 17 to 48 inclusive by using between method
print('this is between methos : ',df['age'].between(17,48).sum())# this is between method 
sum((df['age']>=17) & (df['age']<=48))
# Out:
# this is between methos :  37145
# 37145

# %%
df.columns
# Out:
# Index(['age', 'fnlwgt', 'education', 'marital-status', 'relationship', 'race',
#        'gender', 'hours-per-week', 'income'],
#       dtype='object')

# %%
# 14. Calculate the distribution of workclass Columns?
df['hours-per-week'].describe()
# Out:
# count    48640.000000
# mean        40.431373
# std         12.405278
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours-per-week, dtype: float64

# %%
# 15. How many people are completed the B.tech and M.tech?
df['education'].unique()
# Out:
# array(['11th', 'HS-grad', 'Assoc-acdm', 'Some-college', '10th',
#        'Prof-school', '7th-8th', 'Bachelors', 'Masters', 'Doctorate',
#        '5th-6th', 'Assoc-voc', '9th', '12th', '1st-4th', 'Preschool'],
#       dtype=object)

# %%
sum(df['education']=='Bachelors')
# Out:
# 7979

# %%
sum(df['education']=='Masters')
# Out:
# 2652

# %%
sum((df['education']=='Bachelors') | (df['education']=='Masters'))
# Out:
# 10631

# %%
df.shape
# Out:
# (48640, 9)

# %%
sum(df['education'].isin(['Bachelors','Masters']))
# Out:
# 10631

# %% [markdown]
# # BIVARIENT ANALYSIS
# working with two variables,
# finding relation between two variables

# %%
df.columns
# Out:
# Index(['age', 'fnlwgt', 'education', 'marital-status', 'relationship', 'race',
#        'gender', 'hours-per-week', 'income'],
#       dtype='object')

# %%
sns.boxplot(x='age',y='income',data=df)
# Out:
# <Axes: xlabel='age', ylabel='income'>

# %%
#17. Replace Salary values ['<=50K','>50K'] with 0 and 1
df['income']=df['income'].replace({'<=50K':'0','>50K':'1'})

# %%
df.income.value_counts()
# Out:
# income
# 0    36985
# 1    11655
# Name: count, dtype: int64

# %%
df.head(10)
# Out:
#    age  fnlwgt     education      marital-status   relationship   race  \
# 0   25  226802          11th       Never-married      Own-child  Black
# 1   38   89814       HS-grad  Married-civ-spouse        Husband  White
# 2   28  336951    Assoc-acdm  Married-civ-spouse        Husband  White
# 3   44  160323  Some-college  Married-civ-spouse        Husband  Black
# 4   18  103497  Some-college       Never-married      Own-child  White
# 5   34  198693          10th       Never-married  Not-in-family  White
# 6   29  227026       HS-grad       Never-married      Unmarried  Black
# 7   63  104626   Prof-school  Married-civ-spouse        Husband  White
# 8   24  369667  Some-college       Never-married      Unmarried  White
# 9   55  104996       7th-8th  Married-civ-spouse        Husband  White
#
#    gender  hours-per-week income
# 0    Male              40      0
# 1    Male              50      0
# 2    Male              40      1
# 3    Male              40      1
# ...

# %%
sns.boxplot(x='income',y='age',data=df)
# Out:
# <Axes: xlabel='income', ylabel='age'>

# %%
df.columns
# Out:
# Index(['age', 'fnlwgt', 'education', 'marital-status', 'relationship', 'race',
#        'gender', 'hours-per-week', 'income'],
#       dtype='object')

# %%
# 18. Which Education gatting higher income
df.groupby('education')['income'].mean().sort_values(ascending=False)
# Out:
# education
# 10th                                                          inf
# 11th                                                          inf
# 12th                                                          inf
# 5th-6th                                                       inf
# 7th-8th                                                       inf
# 9th                                                           inf
# Assoc-acdm                                                    inf
# Assoc-voc                                                     inf
# Bachelors                                                     inf
# Doctorate                                                     inf
# HS-grad                                                       inf
# Masters                                                       inf
# Prof-school                                                   inf
# Some-college                                                  inf
# ...

# %%
 #19. who has better chance to get salay women or men above 50K?
df.groupby('gender')['income'].mean()
# Out:
# gender
# Female    inf
# Male      inf
# Name: income, dtype: object

# %%
df.head(2)
# Out:
#    age  fnlwgt education      marital-status relationship   race gender  \
# 0   25  226802      11th       Never-married    Own-child  Black   Male
# 1   38   89814   HS-grad  Married-civ-spouse      Husband  White   Male
#
#    hours-per-week income
# 0              40      0
# 1              50      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48640 entries, 0 to 48841
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48640 non-null  int64
#  1   fnlwgt          48640 non-null  int64
#  2   education       48640 non-null  object
#  3   marital-status  48640 non-null  object
#  4   relationship    48640 non-null  object
#  5   race            48640 non-null  object
#  6   gender          48640 non-null  object
#  7   hours-per-week  48640 non-null  int64
#  8   income          48640 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 3.7+ MB

# %%
df['income'].astype('float')
# Out:
# 0        0.0
# 1        0.0
# 2        1.0
# 3        1.0
# 4        0.0
#         ...
# 48837    0.0
# 48838    1.0
# 48839    0.0
# 48840    0.0
# 48841    1.0
# Name: income, Length: 48640, dtype: float64
